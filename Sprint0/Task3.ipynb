// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта: Система, предоставляющая информацию об учетных записях в банке</h2>
//
// ----
//
// ### Вариант задания №7

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс BankAccount в C#, который будет представлять
// информацию об учетных записях в банке. На основе этого класса разработать 2-3
// производных класса, демонстрирующих принципы наследования и полиморфизма.
// В каждом из классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
//
// Требования к базовому классу BankAccount:
//
// • Атрибуты: Номер счета (AccountNumber), Баланс (Balance), Тип счета
// (AccountType).
//
// • Методы:
//
// o GetInfo(): метод для получения информации о счете в виде строки.
//
// o Deposit(decimal amount): метод для внесения денег на счет.
//
// o Withdraw(decimal amount): метод для снятия денег со счета.
//
// Требования к производным классам:
//
// 1. Сберегательный счет (SavingsAccount): Должен содержать дополнительные
// атрибуты, такие как Процентная ставка (InterestRate). Метод Deposit() должен
// быть переопределен для добавления процентов к сумме вклада при
// внесении денег на счет.
//
// 2. Текущий счет (CheckingAccount): Должен содержать дополнительные
// атрибуты, такие как Лимит овердрафта (OverdraftLimit).
// Метод Withdraw() должен быть переопределен для проверки и применения
// лимита овердрафта при снятии денег со счета.
//
// 3. Инвестиционный счет (InvestmentAccount) (если требуется третий класс):
// Должен содержать дополнительные атрибуты, такие как Список активов
// (AssetsList). Метод GetInfo() должен быть переопределен для включения
// информации о списках активов в описании счета.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class BankAccount
{
    private string accountNumber;
    private decimal balance;
    private string accountType;

    public string AccountNumber
    {
        get { return accountNumber; }
        set { accountNumber = value; }
    }

    public decimal Balance
    {
        get { return balance; }
        set { balance = value; }
    }

    public string AccountType
    {
        get { return accountType; }
        set { accountType = value; }
    }

    public BankAccount(string accountNumber, decimal balance, string accountType)
    {
        AccountNumber = accountNumber;
        Balance = balance;
        AccountType = accountType;
    }

    public virtual void GetInfo()
    {
        Console.WriteLine($"Номер счета: {AccountNumber}, Тип счета: {AccountType}, Баланс: {Balance} р.");
    }

    public virtual void Deposit(decimal amount)
    {
        Balance = Balance + amount;
        Console.WriteLine($"Внесено на счет: {amount} р. Баланс: {Balance} р.");
    }

    public virtual void Withdraw(decimal amount)
    {
        if (Balance >= amount)
        {
            Balance = Balance - amount;
            Console.WriteLine($"Снято со счета: {amount} р. Баланс: {Balance} р.");
        }
        else
        {
            Console.WriteLine($"Недостаточно средств, Баланс: {Balance} р.");
        }
    }
}

public class SavingsAccount : BankAccount
{
    private decimal interestRate;

    public decimal InterestRate
    {
        get { return interestRate; }
        set { interestRate = value; }
    }

    public SavingsAccount(string accountNumber, decimal balance, string accountType, decimal interestRate) : base (accountNumber, balance, accountType)
    {
        InterestRate = interestRate;
    }

    public override void Deposit(decimal amount)
    {
        Balance = Balance + amount;
        decimal percents = Balance * (InterestRate / 100);
        Balance = Balance + percents;
        Console.WriteLine($"Внесено на счет: {amount} р. Начислены проценты {percents} р. Ставка {InterestRate}%, Баланс: {Balance} р.");
    }

    public void IsGoodInterestRate()
    {
        if (InterestRate >= 5)
        {
            Console.WriteLine($"Ваш вклад выгодный! Процентная ставка: {InterestRate}%");
        }
        else
        {
            Console.WriteLine($"Ваш вклад невыгодный! Низкая процентная ставка: {InterestRate}%.");
        }
    }
}

public class CheckingAccount : BankAccount
{
    private decimal overdraftLimit;

    public decimal OverdraftLimit
    {
        get { return overdraftLimit; }
        set { overdraftLimit = value; }
    }

    public CheckingAccount(string accountNumber, decimal balance, string accountType, decimal overdraftLimit) : base(accountNumber, balance, accountType)
    {
        OverdraftLimit = overdraftLimit;
    }

    public override void Withdraw(decimal amount)
    {
        decimal total = Balance + OverdraftLimit;

        if (total >= amount)
        {
            Balance = Balance - amount;
            Console.WriteLine($"Снято со счета: {amount} р. Лимит овердрафта: {OverdraftLimit} р. Баланс: {Balance} р.");
        }
        else
        {
            Console.WriteLine($"Превышен лимит овердрафта, Доступно: {total} р.");
        }
    }
    public bool IsOverdraft()
    {
        if (Balance < 0)
        {
            Console.WriteLine($"На вашем счете {AccountNumber} подключена опция овердрафта. Баланс: {OverdraftLimit} р. Использовано: {Math.Abs(Balance)} из {OverdraftLimit} р.");
            return true;
        }
        else
        {
            Console.WriteLine($"Счет {AccountNumber} в положительном балансе. Баланс: {Balance} р.");
            return false;
        }
        
    }
}

public class InvestmentAccount : BankAccount
{
    private List<string> assetsList;

    public List<string> AssetsList
    {
        get { return assetsList; }
        set { assetsList = value; }
    }

    public InvestmentAccount(string accountNumber, decimal balance, string accountType, List<string> assets) : base(accountNumber, balance, accountType)
    {
        AssetsList = assets;
    }

    public override void GetInfo()
    {
        string asserts = string.Join(", ", AssetsList);
        Console.WriteLine($"Номер счета: {AccountNumber}, Тип счета: {AccountType}, Баланс: {Balance} р. , Активы: {asserts}");
    }

    public void ShowAssetsCount()
    {
        Console.WriteLine($"Количество активов: {AssetsList.Count}");
    }
}

SavingsAccount savingsAccount = new SavingsAccount("1357", 2000, "Сберегательный", 5);
CheckingAccount checkingAccount = new CheckingAccount("2569", 1500, "Текущий", 500);
List<string> assets = new List<string> {"Акции ВТБ", "Акции СБЕР", "Акции Газпромбанк"};
InvestmentAccount investmentAccount = new InvestmentAccount("4807", 1500, "Инвестиционный", assets);

BankAccount bankAccount1 = savingsAccount;
BankAccount bankAccount2 = checkingAccount;
BankAccount bankAccount3 = investmentAccount;

Console.WriteLine("--Сберегательный счет--");
bankAccount1.GetInfo();
bankAccount1.Deposit(700);
bankAccount1.Withdraw(500);
savingsAccount.IsGoodInterestRate();

Console.WriteLine("--Текущий счет--");
bankAccount2.GetInfo();
bankAccount2.Deposit(200);
bankAccount2.Withdraw(400);
checkingAccount.IsOverdraft();

Console.WriteLine("--Инвестиционный счет--");
bankAccount3.GetInfo();
bankAccount3.Deposit(400);
bankAccount3.Withdraw(1000);
investmentAccount.ShowAssetsCount();
// Out:
// --Сберегательный счет--
// Номер счета: 1357, Тип счета: Сберегательный, Баланс: 2000 р.
// Внесено на счет: 700 р. Начислены проценты 135.00 р. Ставка 5%, Баланс: 2835.00 р.
// Снято со счета: 500 р. Баланс: 2335.00 р.
// Ваш вклад выгодный! Процентная ставка: 5%
// --Текущий счет--
// Номер счета: 2569, Тип счета: Текущий, Баланс: 1500 р.
// Внесено на счет: 200 р. Баланс: 1700 р.
// Снято со счета: 400 р. Лимит овердрафта: 500 р. Баланс: 1300 р.
// Счет 2569 в положительном балансе. Баланс: 1300 р.
// --Инвестиционный счет--
// Номер счета: 4807, Тип счета: Инвестиционный, Баланс: 1500 р. , Активы: Акции ВТБ, Акции СБЕР, Акции Газпромбанк
// Внесено на счет: 400 р. Баланс: 1900 р.
// Снято со счета: 1000 р. Баланс: 900 р.
// Количество активов: 3
