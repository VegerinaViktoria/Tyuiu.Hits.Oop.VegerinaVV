// %% [markdown]
// <h1 style="color:DodgerBlue">Создание экземпляров классов (объектов) и взаимодействие объектов между собой</h1>

// %% [markdown]
// ### Создание экземпляров классов (объектов)
//
// В C#, экземпляр класса создается с помощью оператора `new`, который выделяет память для нового объекта и вызывает конструктор класса для инициализации этого объекта. Конструктор — это специальный метод в классе, который имеет то же имя, что и класс, и используется для установки начального состояния объекта.
//
// #### Пример создания экземпляров классов Vehicle и Car
//
// ```csharp
// Vehicle myVehicle = new Vehicle();
// Car myCar = new Car();
// ```
//
// В этом примере создаются два объекта: один для класса `Vehicle` и другой для класса `Car`. Конструкторы этих классов будут автоматически вызваны при создании объектов.
//
// ### Взаимодействие объектов между Собой
//
// Взаимодействие объектов между собой означает, что один объект может вызывать методы другого объекта или обращаться к его свойствам (если они доступны). Это позволяет объектам обмениваться информацией и координировать свои действия.
//
// #### Пример взаимодействия объектов
//
// ```csharp
// myVehicle.Color = "Red";
// myVehicle.Speed = 60;
//
// myCar.Color = "Blue";
// myCar.FuelLevel = 100;
// myCar.Refuel(50); // Увеличиваем уровень топлива на 50
// ```
//
// В этом примере мы устанавливаем свойства `Color` и `Speed` для объекта `myVehicle`, а также свойства `Color` и `FuelLevel` для объекта `myCar`. Затем мы вызываем метод `Refuel` у объекта `myCar`, чтобы увеличить его уровень топлива.
//
// ### Закрепление правил использования модификаторов доступа
//
// Модификаторы доступа определяют уровень доступности членов класса из других частей кода. Важно правильно использовать модификаторы доступа для обеспечения безопасности и инкапсуляции данных.
//
// #### Примеры модификаторов доступа в классах Vehicle и Car
//
// ```csharp
// public class Vehicle
// {
//     public string Color { get; set; } // public свойство
//     private int speed; // private поле
//
//     protected void SetSpeed(int value) // protected метод
//     {
//         speed = value;
//     }
// }
//
// public class Car : Vehicle
// {
//     private int fuelLevel; // private поле
//
//     public void Refuel(int amount) // public метод
//     {
//         fuelLevel += amount;
//     }
//
//     protected void CheckSpeedLimit() // protected метод
//     {
//         if (speed > 120)
//         {
//             Console.WriteLine("Превышен скоростной режим!");
//         }
//     }
// }
// ```
//
// В этом примере:
// - Свойство `Color` в классе `Vehicle` объявлено как `public`, что позволяет доступ к нему из любого места в коде.
// - Поле `speed` в классе `Vehicle` объявлено как `private`, что ограничивает доступ к нему только внутри класса `Vehicle`.
// - Метод `SetSpeed` в классе `Vehicle` объявлен как `protected`, что позволяет доступ к нему из класса `Vehicle` и его производных классов.
// - Поле `fuelLevel` в классе `Car` объявлено как `private`, ограничивая доступ к нему только внутри класса `Car`.
// - Методы `Refuel` и `CheckSpeedLimit` в классе `Car` демонстрируют использование модификаторов доступа для контроля над тем, как объекты могут взаимодействовать друг с другом.
//
// ### Заключение
//
// Создание экземпляров классов и взаимодействие между объектами являются ключевыми аспектами объектно-ориентированного программирования в C#. Правильное использование модификаторов доступа обеспечивает безопасность данных и инкапсуляцию, позволяя разработчикам создавать более надежные и управляемые программы.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Car и Vehicle ниже в блоке:</h4>
//
// ----

// %%
public class Vehicle
{
    public string Color { get; set; }
    private int speed;

    protected void SetSpeed(int value)
    {
        speed = value;
    }

    public int Speed
    {
        get { return speed; }
    }

    public void Accelerate(int delta)
    {
        SetSpeed(speed + delta);
        Console.WriteLine($"Скорость увеличена на {delta} км/ч. Текущая скорость: {speed} км/ч.");
    }
}

public class Car : Vehicle
{
    private int fuelLevel;

    public int FuelLevel
    {
        get { return fuelLevel; }
        set { fuelLevel = value; }
    }

    public void Refuel(int amount)
    {
        fuelLevel += amount;
        Console.WriteLine($"Количество топлива увеличено на {amount} л. Всего топлива: {fuelLevel} л.");
    }

    protected void CheckSpeedLimit()
    {
        if (Speed > 120)
        {
            Console.WriteLine("Превышен скоростной режим!");
        }
        else
        {
            Console.WriteLine("Скоростной режим соблюден!");
        }
    }

    public void CheckSpeed()
    {
        CheckSpeedLimit();
    }
}

Vehicle myVehicle = new Vehicle();
Car myCar = new Car();

myVehicle.Color = "Red";
Console.WriteLine($"Цвет транспорта: {myVehicle.Color}, скорость: {myVehicle.Speed} км/ч");
myVehicle.Accelerate(50);
Console.WriteLine($"Tранспортное средство цвета {myVehicle.Color} движется со скоростью {myVehicle.Speed} км/ч.");


myCar.Color = "Blue";
myCar.FuelLevel = 20;
Console.WriteLine($"Цвет машины: {myCar.Color}, уровень топлива: {myCar.FuelLevel} л.");
myCar.Accelerate(130);
Console.WriteLine($"Машина цвета {myCar.Color} движется со скоростью {myCar.Speed} км/ч.");
myCar.Refuel(40);
myCar.CheckSpeed();
// Out:
// Цвет транспорта: Red, скорость: 0 км/ч
// Скорость увеличена на 50 км/ч. Текущая скорость: 50 км/ч.
// Tранспортное средство цвета Red движется со скоростью 50 км/ч.
// Цвет машины: Blue, уровень топлива: 20 л.
// Скорость увеличена на 130 км/ч. Текущая скорость: 130 км/ч.
// Машина цвета Blue движется со скоростью 130 км/ч.
// Количество топлива увеличено на 40 л. Всего топлива: 60 л.
// Превышен скоростной режим!

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (2-3 например Dog, Cat и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также статические и обычными атрибуты и метода класса с реализацией взаимодействия между объектами.

// %%
public class Animal
{
    public string Color {get; set; }
    private string _name;
    private int _age;

    public string Name
    {
        get { return _name; }
        set { _name = value; }
    }

    public int Age
    {
        get { return _age; }
        set
        {
            if (value >= 0)
                _age = value;
            else
                throw new ArgumentOutOfRangeException("Возраст не может быть отрицательным!");
        }
    }
    
    public static int TotalAnimals {get; private set; } = 0;
    
    public Animal()
    {
        TotalAnimals++;
    }

    public void Grow(int amount)
    {
        Age += amount;
        Console.WriteLine($"Животное {Name} выросло на {amount} лет. Текущий возраст: {Age} лет");   
    }

    public void Eat()
    {
        Console.WriteLine($"Животное {Name} ест");
    }

    public void PlayWith(Animal other)
    {
        Console.WriteLine($"{Name} играет с {other.Name}");
    }

    public static void DisplayTotalAnimals()
    {
        Console.WriteLine($"Общее количество животных: {TotalAnimals}");
    }

}

public class Cat : Animal
{
    private int _mice;

    public int Mice
    {
        get { return _mice; }
        set { _mice = value; }
    }

    public Cat() :base()
    {
        Mice = 0;
    }

    public void MakeMeow()
    {
        Console.WriteLine($"Кошка {Name} мяукает");
    }

    public void CatchMice(int amount)
    {
        Mice += amount;
        Console.WriteLine($"Кошка {Name} поймала {amount} мышей. Всего мышей поймано: {Mice}");
    }
}

public class Dog : Animal
{
    private int _bones;

    public int Bones
    {
        get { return _bones; }
        set { _bones = value; }
    }

    public Dog() :base()
    {
        Bones = 0;
    }

    public void MakeBark()
    {
        Console.WriteLine($"Собака {Name} лает");
    }

    public void FindBone(int amount)
    {
        Bones += amount;
        Console.WriteLine($"Собака {Name} нашла {amount} косточек. Всего косточек найдено: {Bones}");
    }
}

public class Bird : Animal
{
    private int _feathers;

    public int Feathers
    {
        get { return _feathers; }
        set { _feathers = value; }
    }

    public Bird() :base()
    {
        Feathers = 2000;
    }

    public void MakeSing()
    {
        Console.WriteLine($"Птичка {Name} чирикает");
    }

    public void LoseFeathers(int amount)
    {
        Feathers -= amount;
        Console.WriteLine($"У птички {Name} выпало {amount} перьев. Осталось перьев: {Feathers}");
    }
}

Cat myCat = new Cat();
myCat.Name = "Буся";
myCat.Age = 12;
myCat.Color = "Серый";

Dog myDog = new Dog();
myDog.Name = "Бублик";
myDog.Age = 5;
myDog.Color = "Коричневый";

Bird myBird = new Bird();
myBird.Name = "Тучка";
myBird.Age = 2;
myBird.Color = "Каштановый";

Console.WriteLine($"Кошка: {myCat.Name}, возраст: {myCat.Age} лет, окрас: {myCat.Color}");
Console.WriteLine($"Собака: {myDog.Name}, возраст: {myDog.Age} лет, окрас: {myDog.Color}");
Console.WriteLine($"Птичка: {myBird.Name}, возраст: {myBird.Age} лет, окрас: {myBird.Color}");

myCat.Grow(1);
myCat.Eat();
myCat.MakeMeow();
myCat.CatchMice(5);

myDog.Grow(2);
myDog.Eat();
myDog.MakeBark();
myDog.FindBone(4);

myBird.Grow(1);
myBird.Eat();
myBird.MakeSing();
myBird.LoseFeathers(50);

myCat.PlayWith(myDog);
myDog.PlayWith(myBird);
myBird.PlayWith(myCat);

Animal.DisplayTotalAnimals();
// Out:
// Кошка: Буся, возраст: 12 лет, окрас: Серый
// Собака: Бублик, возраст: 5 лет, окрас: Коричневый
// Птичка: Тучка, возраст: 2 лет, окрас: Каштановый
// Животное Буся выросло на 1 лет. Текущий возраст: 13 лет
// Животное Буся ест
// Кошка Буся мяукает
// Кошка Буся поймала 5 мышей. Всего мышей поймано: 5
// Животное Бублик выросло на 2 лет. Текущий возраст: 7 лет
// Животное Бублик ест
// Собака Бублик лает
// Собака Бублик нашла 4 косточек. Всего косточек найдено: 4
// Животное Тучка выросло на 1 лет. Текущий возраст: 3 лет
// Животное Тучка ест
// Птичка Тучка чирикает
// У птички Тучка выпало 50 перьев. Осталось перьев: 1950
// Буся играет с Бублик
// Бублик играет с Тучка
// Тучка играет с Буся
// Общее количество животных: 3
